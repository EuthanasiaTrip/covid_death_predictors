# %%
#!pip install -q git+https://github.com/keras-team/keras-nlp.git --upgrade

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
folder_path = '/content/gdrive/MyDrive/text-classifier/'

# %%
import pandas as pd
import json

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from tensorflow.keras import Input, Model, Sequential, regularizers
from tensorflow.keras.layers import concatenate,TimeDistributed, Concatenate, GRU, Activation, SpatialDropout2D, Dropout, Flatten,SeparableConv1D, Dense, SimpleRNN, LSTM, Conv1D, Reshape,MaxPooling1D, Conv2D, Reshape,MaxPooling2D, Permute,Bidirectional, BatchNormalization, DepthwiseConv2D, GlobalMaxPooling2D
from tensorflow.keras.layers import concatenate, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,Callback#training callbacks
from tensorflow.keras import optimizers
from tensorflow.keras import models
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split
from ast import literal_eval

import matplotlib.pyplot as plt
import numpy as np

# %%
data_path = folder_path + 'data-set-rows.json'

with open(data_path) as data_file:
  data_text = data_file.read()  
  # убираем BOM-символ из json файла
  data = json.loads(data_text.lstrip('\ufeff'))
  df = pd.DataFrame(data)

print('Total rows:', len(df))
print('Duplicates:', sum(df["TextLine"].duplicated()))
# Out:
# Total rows: 2043
# Duplicates: 415

# %% [markdown]
# drop duplicates

# %%
df = df[~df["TextLine"].duplicated()]
print('Deduplicated rows:', len(df))
# Out:
# Deduplicated rows: 1628

# %%
#print(df.info)
print(df.shape)
print(df.columns.values)
print(df.head(20))
# Out:
# (1628, 2)
# ['TextLine' 'Parameters']
#                                              TextLine Parameters
# 0                              пневмония, КТ-2, ДН 0         [0]
# 2   дыхание, першение в горле, головная боль, одыш...        [0]
# 3   Жалобы: слабость общая умеренная, сухой со сви...        [0]
# 4   Жалобы: слабость общая умеренная, сухой, одышк...        [0]
# 5   Жалобы: слабость общая умеренная, сухой, одышк...        [0]
# 6   Жалобы: слабость общая умеренная,кашель сухой,...        [0]
# 7   Лейкоциты (WBC) 11.56 10Е9/л (3.80 - 11.80) Ли...        [1]
# 8   10Е9/л (1.70 - 7.60) Базофилы # (Bas) 0.04 10Е...         []
# 11  Лейкоциты (WBC) 14.32 10Е9/л (3.80 - 11.80) Ли...        [1]
# 13                         одышка при фн выраженная.         [0]
# 14  одышка при фн выраженная, к ночи чувство распи...        [0]
# 15  одышка в покое, к ночи чувство распирание в го...        [0]
# 16  одышка в покое, не может спать на животе ввиду...        [0]
# 18  Лейкоциты (WBC) 9.23 10Е9/л (3.80 - 11.80) Лим...        [1]
# 19  одышка в покое, не может спать на животе ввиду...        [0]
# 20  Жалобы: слабость общая умеренная, кашель сухой...        [0]
# 22  Лейкоциты (WBC) 9.23 10Е9/л (3.80 - 11.80) Лим...        [1]
# 25  Лейкоциты (WBC) 8.28 10Е9/л (3.80 - 11.80) Лим...        [1]
# 26  - 5.0) сегментоядерные нейтрофилы 66.0 % (47.0...         []
# 27  0.0) метамиелоциты 1.0 % (0.0 - 0.0) Скорость ...         []

# %%
#change labeling style
for i in range(len(df)):
  #нет параметров
  if (df.iloc[i]['Parameters'])==[]:
    df.iloc[i]['Parameters']=0
  #одышка при фн
  if (df.iloc[i]['Parameters'])==[0]:
    df.iloc[i]['Parameters']=1
  #лимфоциты абс
  if (df.iloc[i]['Parameters'])==[1]:
    df.iloc[i]['Parameters']=2

# %%
#print(df.info)
print(df.shape)
print(df.columns.values)
print(df.head(20))
# Out:
# (1628, 2)
# ['TextLine' 'Parameters']
#                                              TextLine Parameters
# 0                              пневмония, КТ-2, ДН 0           1
# 2   дыхание, першение в горле, головная боль, одыш...          1
# 3   Жалобы: слабость общая умеренная, сухой со сви...          1
# 4   Жалобы: слабость общая умеренная, сухой, одышк...          1
# 5   Жалобы: слабость общая умеренная, сухой, одышк...          1
# 6   Жалобы: слабость общая умеренная,кашель сухой,...          1
# 7   Лейкоциты (WBC) 11.56 10Е9/л (3.80 - 11.80) Ли...          2
# 8   10Е9/л (1.70 - 7.60) Базофилы # (Bas) 0.04 10Е...          0
# 11  Лейкоциты (WBC) 14.32 10Е9/л (3.80 - 11.80) Ли...          2
# 13                         одышка при фн выраженная.           1
# 14  одышка при фн выраженная, к ночи чувство распи...          1
# 15  одышка в покое, к ночи чувство распирание в го...          1
# 16  одышка в покое, не может спать на животе ввиду...          1
# 18  Лейкоциты (WBC) 9.23 10Е9/л (3.80 - 11.80) Лим...          2
# 19  одышка в покое, не может спать на животе ввиду...          1
# 20  Жалобы: слабость общая умеренная, кашель сухой...          1
# 22  Лейкоциты (WBC) 9.23 10Е9/л (3.80 - 11.80) Лим...          2
# 25  Лейкоциты (WBC) 8.28 10Е9/л (3.80 - 11.80) Лим...          2
# 26  - 5.0) сегментоядерные нейтрофилы 66.0 % (47.0...          0
# 27  0.0) метамиелоциты 1.0 % (0.0 - 0.0) Скорость ...          0

# %%
#print values
data_with_two_params = list(filter(lambda x: x == 0, df['Parameters']))
data_with_one_params = list(filter(lambda x: x == 1, df['Parameters']))
data_with_zero_params = list(filter(lambda x:  x == 2, df['Parameters']))
print(len(data_with_two_params))
print(len(data_with_one_params))
print(len(data_with_zero_params))
# Out:
# 634
# 798
# 196

# %%
#preprocess the data
import re
to_exclude = '»«$&()*+-/<=>@[\\]^_`{|}~\t\n'#excluded symbols
to_tokenize = '.,:!?";%#'#processed symbols

data_length = len(df.index)

for i in range(data_length):
    df.iloc[i]["TextLine"]=re.sub(r'(['+to_tokenize+'])', r' \1 ', df.iloc[i]['TextLine'])

    if i%100==0:
      print(df.iloc[i])
# Out:
# TextLine        пневмония ,  КТ-2 ,  ДН 0
# Parameters                               1
# Name: 0, dtype: object
# TextLine      гемоглобина (MCHC) 310 . 00 г/л (323 . 00 - 35...
# Parameters                                                    2
# Name: 112, dtype: object
# TextLine      Основной :  Коронавирусная инфекция ,  вызванн...
# Parameters                                                    0
# Name: 218, dtype: object
# TextLine       Жалобы :  кашель малопродуктивный .  боль в н...
# Parameters                                                    0
# Name: 338, dtype: object
# TextLine       Доступные и значимые данные лабораторных и ин...
# Parameters                                                    0
# Name: 446, dtype: object
# TextLine      На протяжении обоих легких участки уплотнения ...
# Parameters                                                    1
# Name: 567, dtype: object
# TextLine      Диагноз :  Основное заболевание Короновирусная...
# Parameters                                                    1
# Name: 680, dtype: object
# TextLine      одышку при мин . нагрузке  ,  отечность ног  ....
# Parameters                                                    1
# Name: 802, dtype: object
# TextLine       Анамнез :  находится на лечении в ОРИТ инфекц...
# Parameters                                                    1
# Name: 909, dtype: object
# TextLine         Общий анализ крови от 29 . 12 . 2021 :  Лей...
# Parameters                                                    2
# Name: 1032, dtype: object
# TextLine      (17 . 01 . 2022) :  К-т вариации ширины распре...
# Parameters                                                    2
# Name: 1154, dtype: object
# TextLine       Дыхание проводится во все отделы ,  жесткое ....
# Parameters                                                    1
# Name: 1290, dtype: object
# TextLine       Дыхание проводится во все отделы ,  жесткое ....
# Parameters                                                    1
# Name: 1422, dtype: object
# TextLine      (17 . 01 . 2022) :  Лейкоциты (WBC) 7 . 59 10Е...
# Parameters                                                    0
# Name: 1548, dtype: object
# TextLine      > Лейкоциты (WBC) 10 . 03 10Е9/л (4 . 00 - 10 ...
# Parameters                                                    2
# Name: 1687, dtype: object
# TextLine      Общий анализ крови > Лейкоциты (WBC) 12 . 14 1...
# Parameters                                                    2
# Name: 1853, dtype: object
# TextLine      Диагноз сопутствующий ,  осложнения Двусторонн...
# Parameters                                                    1
# Name: 2008, dtype: object

# %%
text_subframe = df["TextLine"]
max_len = 50
num_words = 6000

tokenizer_text = Tokenizer(num_words=num_words, filters=to_exclude, oov_token='UNK')

tokenizer_text.fit_on_texts(text_subframe)

tokenizer_text.word_index
# Out:
# {'UNK': 1,
#  '.': 2,
#  ',': 3,
#  'в': 4,
#  '00': 5,
#  'л': 6,
#  '0': 7,
#  ':': 8,
#  '%': 9,
#  'на': 10,
#  ';': 11,
#  '3': 12,
#  '1': 13,
#  '10': 14,
#  'мин': 15,
#  '2': 16,
#  'при': 17,
#  'с': 18,
#  '10е9': 19,
#  'не': 20,
#  '4': 21,
#  'сатурация': 22,
#  'одышка': 23,
#  'ст': 24,
#  '20': 25,
#  '5': 26,
#  'дыхание': 27,
#  '50': 28,
#  'хрипы': 29,
#  '80': 30,
#  'и': 31,
#  '#': 32,
#  '11': 33,
#  'кислорода': 34,
#  'чд': 35,
#  'пневмония': 36,
#  'дн': 37,
#  'нет': 38,
#  'г': 39,
#  'мм': 40,
#  '19': 41,
#  'по': 42,
#  '2021': 43,
#  'лимфоциты': 44,
#  'двусторонняя': 45,
#  'фн': 46,
#  '70': 47,
#  '7': 48,
#  'жалобы': 49,
#  'дыхания': 50,
#  '30': 51,
#  'кислороде': 52,
#  'нагрузке': 53,
#  'воздухе': 54,
#  'акте': 55,
#  '12': 56,
#  'во': 57,
#  'кт': 58,
#  '36': 59,
#  'внебольничная': 60,
#  '40': 61,
#  'вспомогательная': 62,
#  'участвует': 63,
#  'мускулатура': 64,
#  '90': 65,
#  'отделы': 66,
#  'все': 67,
#  'проводится': 68,
#  'от': 69,
#  'вирусная': 70,
#  'состояние': 71,
#  '60': 72,
#  '21': 73,
#  'лейкоциты': 74,
#  'увлажненном': 75,
#  '8': 76,
#  'сидя': 77,
#  'инфекция': 78,
#  'слабость': 79,
#  '15': 80,
#  'рнк': 81,
#  'жесткое': 82,
#  'рт': 83,
#  'отсутствуют': 84,
#  'wbc': 85,
#  'диагноз': 86,
#  'до': 87,
#  'отделах': 88,
#  '6': 89,
#  '18': 90,
#  'covid': 91,
#  'нижних': 92,
#  'покое': 93,
#  'ед': 94,
#  'коронавирусная': 95,
#  'lym': 96,
#  'температура': 97,
#  'степени': 98,
#  '96': 99,
#  'крови': 100,
#  '06': 101,
#  '?': 102,
#  'тяжести': 103,
#  '98': 104,
#  'мг': 105,
#  '22': 106,
#  'эритроциты': 107,
#  'общий': 108,
#  'положении': 109,
#  '16': 110,
#  '!': 111,
#  'средней': 112,
#  'одышку': 113,
#  'чсс': 114,
#  '01': 115,
#  'отрицательно': 116,
#  '10е12': 117,
#  'нейтрофилы': 118,
#  'ммоль': 119,
#  'сторон': 120,
#  '95': 121,
#  'фл': 122,
#  'гемоглобин': 123,
#  'rbc': 124,
#  'сердца': 125,
#  'кашель': 126,
#  '31': 127,
#  '35': 128,
#  'гемоглобина': 129,
#  '2022': 130,
#  'течение': 131,
#  'hgb': 132,
#  'lymf': 133,
#  'риск': 134,
#  'пцр': 135,
#  '25': 136,
#  'живот': 137,
#  'осложнение': 138,
#  '17': 139,
#  'без': 140,
#  'болезнь': 141,
#  'тяжелое': 142,
#  'недостаточность': 143,
#  'к': 144,
#  'гипертоническая': 145,
#  'терапии': 146,
#  'эритроцитов': 147,
#  'plt': 148,
#  'тромбоциты': 149,
#  '97': 150,
#  'моноциты': 151,
#  'мягкий': 152,
#  '320': 153,
#  'терапия': 154,
#  '14': 155,
#  'справа': 156,
#  'о2': 157,
#  '180': 158,
#  '24': 159,
#  'общее': 160,
#  '43': 161,
#  '23': 162,
#  'гематокрит': 163,
#  '03': 164,
#  '07': 165,
#  '02': 166,
#  '13': 167,
#  '100': 168,
#  'левой': 169,
#  '130': 170,
#  'сознание': 171,
#  '73': 172,
#  '37': 173,
#  '26': 174,
#  '45': 175,
#  'белок': 176,
#  'после': 177,
#  '38': 178,
#  '–': 179,
#  'через': 180,
#  'о': 181,
#  'эозинофилы': 182,
#  '120': 183,
#  'hct': 184,
#  'ос': 185,
#  'легких': 186,
#  'безболезненный': 187,
#  'давление': 188,
#  '55': 189,
#  'за': 190,
#  'мкмоль': 191,
#  'ибс': 192,
#  'объем': 193,
#  'ширины': 194,
#  'распределения': 195,
#  '92': 196,
#  'минимальной': 197,
#  'потоке': 198,
#  '94': 199,
#  'ясное': 200,
#  'средний': 201,
#  'сохраняется': 202,
#  'базофилы': 203,
#  'mon': 204,
#  'rdw': 205,
#  'крепитирующие': 206,
#  'мелкопузырчатые': 207,
#  '85': 208,
#  'обычной': 209,
#  'артериальное': 210,
#  'ослаблено': 211,
#  'bas': 212,
#  'eos': 213,
#  'малопродуктивный': 214,
#  'слева': 215,
#  'neu': 216,
#  '99': 217,
#  'т': 218,
#  'фоне': 219,
#  'ослабленное': 220,
#  'стул': 221,
#  'лфк': 222,
#  'мл': 223,
#  'осл': 224,
#  'контроль': 225,
#  'кожный': 226,
#  'покров': 227,
#  'mchc': 228,
#  'сопутствующий': 229,
#  'хсн': 230,
#  'лечение': 231,
#  'п': 232,
#  '04': 233,
#  '28': 234,
#  'анализ': 235,
#  'отеки': 236,
#  'вирусно': 237,
#  'бактериальная': 238,
#  'полисегментарная': 239,
#  '9': 240,
#  '140': 241,
#  'признаки': 242,
#  'ад': 243,
#  'уд': 244,
#  'фк': 245,
#  'общая': 246,
#  '93': 247,
#  '65': 248,
#  'основного': 249,
#  '91': 250,
#  'двух': 251,
#  'боку': 252,
#  'данные': 253,
#  'одн': 254,
#  '08': 255,
#  'м': 256,
#  'чистый': 257,
#  '160': 258,
#  'скорость': 259,
#  '63': 260,
#  'лечения': 261,
#  '09': 262,
#  '42': 263,
#  'отделение': 264,
#  'из': 265,
#  '05': 266,
#  'нк': 267,
#  '27': 268,
#  '75': 269,
#  'увеличена': 270,
#  'кожные': 271,
#  'покровы': 272,
#  'циб': 273,
#  'фв': 274,
#  'аппетит': 275,
#  'стандартное': 276,
#  'типа': 277,
#  '"': 278,
#  'окраски': 279,
#  'симптомы': 280,
#  'анамнез': 281,
#  'средняя': 282,
#  'печень': 283,
#  '33': 284,
#  'конц': 285,
#  'минуту': 286,
#  '86': 287,
#  'области': 288,
#  'н': 289,
#  'грудной': 290,
#  'поступлении': 291,
#  'кт2': 292,
#  'сахарный': 293,
#  'б': 294,
#  'ii': 295,
#  'латеропозиции': 296,
#  'ла': 297,
#  'отклонение': 298,
#  'экг': 299,
#  'раздражения': 300,
#  'брюшины': 301,
#  'кровати': 302,
#  '89': 303,
#  '53': 304,
#  'пульс': 305,
#  'выслушиваются': 306,
#  'декомпенсация': 307,
#  'креатинин': 308,
#  'х': 309,
#  'коррекция': 310,
#  'тоны': 311,
#  'соп': 312,
#  '2ст': 313,
#  'алт': 314,
#  '106': 315,
#  'гипертензия': 316,
#  'заболевания': 317,
#  'боли': 318,
#  'аст': 319,
#  'маску': 320,
#  '54': 321,
#  '32': 322,
#  'д': 323,
#  'рекомендации': 324,
#  'увл': 325,
#  'со': 326,
#  '72': 327,
#  '44': 328,
#  '29': 329,
#  'типу': 330,
#  'единичные': 331,
#  'мочевина': 332,
#  'отсутствует': 333,
#  'больного': 334,
#  '4ст': 335,
#  'нрс': 336,
#  'пг': 337,
#  'реактивный': 338,
#  'билирубин': 339,
#  'день': 340,
#  'кишечника': 341,
#  'нарушения': 342,
#  'вызванная': 343,
#  'митральная': 344,
#  '323': 345,
#  '356': 346,
#  '62': 347,
#  'среднее': 348,
#  'mch': 349,
#  'стадии': 350,
#  '84': 351,
#  '88': 352,
#  'назначен': 353,
#  'вирус': 354,
#  'трикуспидальная': 355,
#  '66': 356,
#  'sd': 357,
#  'сек': 358,
#  'полости': 359,
#  'самостоятельное': 360,
#  'язык': 361,
#  'идентифицирован': 362,
#  'левого': 363,
#  'атмосферном': 364,
#  'зев': 365,
#  'градиент': 366,
#  'легочная': 367,
#  'выявлено': 368,
#  'тромбоцита': 369,
#  'mpv': 370,
#  'увлажненным': 371,
#  'микроциркуляции': 372,
#  'огк': 373,
#  'проекции': 374,
#  'гб': 375,
#  'обеих': 376,
#  '47': 377,
#  'эритроцита': 378,
#  'mcv': 379,
#  'сд': 380,
#  'новая': 381,
#  'исследований': 382,
#  '48': 383,
#  'время': 384,
#  'заключение': 385,
#  'поведение': 386,
#  'больше': 387,
#  'фп': 388,
#  'содерж': 389,
#  'фибриноген': 390,
#  'лабораторных': 391,
#  'перистальтика': 392,
#  'mm': 393,
#  'hg': 394,
#  'ритмичные': 395,
#  'атеросклероз': 396,
#  'ухудшение': 397,
#  'кислородом': 398,
#  'лицевую': 399,
#  'нормальная': 400,
#  'влажный': 401,
#  'физ': 402,
#  'краткий': 403,
#  'проведенное': 404,
#  'основной': 405,
#  'продолжена': 406,
#  'хороший': 407,
#  'адекватное': 408,
#  'бледен': 409,
#  'кг': 410,
#  'влажные': 411,
#  'стопы': 412,
#  'диабет': 413,
#  'физической': 414,
#  '39': 415,
#  'а': 416,
#  'индекс': 417,
#  'з': 418,
#  '83': 419,
#  '№': 420,
#  'движения': 421,
#  'несколько': 422,
#  'nyha': 423,
#  'отеков': 424,
#  'отделов': 425,
#  'вариации': 426,
#  'мно': 427,
#  'ачтв': 428,
#  'клетки': 429,
#  'iii': 430,
#  'для': 431,
#  'основные': 432,
#  'клинические': 433,
#  'чистые': 434,
#  'ожирение': 435,
#  '71': 436,
#  'обследования': 437,
#  '115': 438,
#  'гликемии': 439,
#  '325': 440,
#  '363': 441,
#  '56': 442,
#  'правой': 443,
#  '61': 444,
#  'р': 445,
#  '41': 446,
#  'гранулоциты': 447,
#  'рвота': 448,
#  'альбумины': 449,
#  'поступил': 450,
#  'больницу': 451,
#  'ознакомлена': 452,
#  'поддержка': 453,
#  'мозга': 454,
#  'соvid': 455,
#  'ч': 456,
#  '78': 457,
#  'утром': 458,
#  'динамике': 459,
#  '87': 460,
#  'требует': 461,
#  'креатинкиназа': 462,
#  '76': 463,
#  'gran': 464,
#  'тела': 465,
#  'умеренно': 466,
#  '82': 467,
#  'прон': 468,
#  'oc': 469,
#  'позиции': 470,
#  'палата': 471,
#  'оарит': 472,
#  '2021г': 473,
#  'общую': 474,
#  'ак': 475,
#  '68': 476,
#  'хлс': 477,
#  'пикс': 478,
#  'сухой': 479,
#  '46': 480,
#  '64': 481,
#  'димер': 482,
#  'протромбиновый': 483,
#  'органы': 484,
#  '3ст': 485,
#  'доступные': 486,
#  'значимые': 487,
#  'инструментальных': 488,
#  '34': 489,
#  'доп': 490,
#  'операции': 491,
#  'приглушены': 492,
#  'регургитация': 493,
#  'сыпь': 494,
#  'артерий': 495,
#  'пределах': 496,
#  'впервые': 497,
#  'кожи': 498,
#  '1ст': 499,
#  'глюкоза': 500,
#  'клаусу': 501,
#  'небольшой': 502,
#  'лечении': 503,
#  'осмотрена': 504,
#  'обнаружено': 505,
#  'самостоятельно': 506,
#  'дилятация': 507,
#  'головного': 508,
#  'кардиомегалия': 509,
#  'выявленный': 510,
#  'хроническая': 511,
#  'давности': 512,
#  'кое': 513,
#  'нг': 514,
#  'комбинированного': 515,
#  'легочной': 516,
#  'синдром': 517,
#  'потока': 518,
#  'ногах': 519,
#  'состояния': 520,
#  'правого': 521,
#  'сохранены': 522,
#  'раз': 523,
#  'пневмонии': 524,
#  'планируемая': 525,
#  'манипуляции': 526,
#  'аокб': 527,
#  'осложнения': 528,
#  '58': 529,
#  'ее': 530,
#  'продолжить': 531,
#  'аорты': 532,
#  'нечастый': 533,
#  'ph': 534,
#  'ветвей': 535,
#  'тяжёлое': 536,
#  'палочкоядерные': 537,
#  'голени': 538,
#  'мкг': 539,
#  'лж': 540,
#  'периферические': 541,
#  'селезенка': 542,
#  'оформленный': 543,
#  'потоком': 544,
#  'было': 545,
#  'ритм': 546,
#  'инотропная': 547,
#  'есть': 548,
#  '21г': 549,
#  'спине': 550,
#  'питания': 551,
#  'осмотра': 552,
#  'оим': 553,
#  'дн1': 554,
#  'ишемия': 555,
#  'перевязки': 556,
#  '10л': 557,
#  'кетоацидоз': 558,
#  'сидит': 559,
#  'тбс': 560,
#  'выраженная': 561,
#  'оседания': 562,
#  'панченкову': 563,
#  '51': 564,
#  '49': 565,
#  'повышение': 566,
#  'диафрагмы': 567,
#  'исследования': 568,
#  'увеличены': 569,
#  'увеличен': 570,
#  '110': 571,
#  'пальпируется': 572,
#  'хобл': 573,
#  'сухие': 574,
#  'наблюдение': 575,
#  'обоих': 576,
#  'правых': 577,
#  'клетке': 578,
#  'легкие': 579,
#  'описание': 580,
#  'сутки': 581,
#  'относительная': 582,
#  'уточнения': 583,
#  'acinetobacter': 584,
#  'средних': 585,
#  'гликемия': 586,
#  'недостаточности': 587,
#  'имт': 588,
#  'м2': 589,
#  'хбп': 590,
#  'может': 591,
#  'сегментоядерные': 592,
#  'вен': 593,
#  'мазок': 594,
#  'конечностях': 595,
#  'дней': 596,
#  '59': 597,
#  'или': 598,
#  'ферритин': 599,
#  'r': 600,
#  'объеме': 601,
#  'консультация': 602,
#  'получает': 603,
#  'болезни': 604,
#  'анамнезом': 605,
#  'динамика': 606,
#  'отмечает': 607,
#  'сравнении': 608,
#  'снижена': 609,
#  '74': 610,
#  'изменений': 611,
#  'стенки': 612,
#  'более': 613,
#  'тромбоза': 614,
#  'остановки': 615,
#  'слр': 616,
#  'анемия': 617,
#  'рг': 618,
#  'скорости': 619,
#  'рисунок': 620,
#  'ат': 621,
#  'палате': 622,
#  'зрачки': 623,
#  'пронпозиции': 624,
#  'дополнений': 625,
#  'атм': 626,
#  'плановая': 627,
#  'абт': 628,
#  'активности': 629,
#  'пальпации': 630,
#  'снижение': 631,
#  'нарастание': 632,
#  'p': 633,
#  'вирусной': 634,
#  'диагнозом': 635,
#  'мочеиспускание': 636,
#  'миокарда': 637,
#  'переводе': 638,
#  'норма': 639,
#  'igm': 640,
#  '57': 641,
#  'стенокардия': 642,
#  'напряжения': 643,
#  'аскс': 644,
#  'бледные': 645,
#  '22г': 646,
#  'смене': 647,
#  'положения': 648,
#  'диабет2': 649,
#  'неудовлетворительный': 650,
#  'меланома': 651,
#  'лечени': 652,
#  'метастазы': 653,
#  'одышки': 654,
#  'температурит': 655,
#  'вич': 656,
#  'свистящие': 657,
#  'лежа': 658,
#  'c': 659,
#  'лимфоузлы': 660,
#  'фотореакция': 661,
#  'вздут': 662,
#  'лактатдегидрогеназа': 663,
#  'активно': 664,
#  'функции': 665,
#  'что': 666,
#  'введение': 667,
#  'у': 668,
#  '77': 669,
#  'органов': 670,
#  'дилатация': 671,
#  'сила': 672,
#  'суставах': 673,
#  'онмк': 674,
#  'головокружение': 675,
#  'мв': 676,
#  'пациент': 677,
#  'находится': 678,
#  'немного': 679,
#  'зависимость': 680,
#  'заболевание': 681,
#  'жестковатое': 682,
#  'под': 683,
#  'бест': 684,
#  'st': 685,
#  't': 686,
#  'уровне': 687,
#  'динамики': 688,
#  's': 689,
#  'раза': 690,
#  'назначения': 691,
#  'fio2': 692,
#  'd': 693,
#  'пжк': 694,
#  'тазовые': 695,
#  'цель': 696,
#  'выражены': 697,
#  'стабильное': 698,
#  'счет': 699,
#  '67': 700,
#  'прямой': 701,
#  'носовое': 702,
#  'уровень': 703,
#  'скт': 704,
#  'кровообращения': 705,
#  'нарушений': 706,
#  '81': 707,
#  'снижен': 708,
#  'баллов': 709,
#  'момент': 710,
#  'аортальная': 711,
#  'пользуется': 712,
#  'створок': 713,
#  'определяется': 714,
#  'po2': 715,
#  'baumannii': 716,
#  'снижается': 717,
#  'среднепузырчатые': 718,
#  'гидроторакс': 719,
#  'медикаментозно': 720,
#  'постели': 721,
#  'пролежень': 722,
#  'ноги': 723,
#  'экхимозы': 724,
#  'i': 725,
#  'режиме': 726,
#  '195': 727,
#  '450': 728,
#  'тип': 729,
#  'сп': 730,
#  'биохимические': 731,
#  'условиях': 732,
#  'инфузионная': 733,
#  'инфекционное': 734,
#  'инфильтрация': 735,
#  'врачом': 736,
#  'артерии': 737,
#  'небольшая': 738,
#  'памперс': 739,
#  '105': 740,
#  'пищи': 741,
#  'я': 742,
#  'пациента': 743,
#  'pco2': 744,
#  'короновирусная': 745,
#  'обследование': 746,
#  'прокальцитонин': 747,
#  'энцефалопатия': 748,
#  'трубку': 749,
#  'успешная': 750,
#  'состояний': 751,
#  '0г': 752,
#  'ккал': 753,
#  'кровотечение': 754,
#  'чсж': 755,
#  '2а': 756,
#  'сепсиса': 757,
#  'ковид': 758,
#  'стенке': 759,
#  'количество': 760,
#  'переведена': 761,
#  'вектор': 762,
#  'отд': 763,
#  'полном': 764,
#  'влажности': 765,
#  'счёт': 766,
#  'подтвержденная': 767,
#  'ходьбе': 768,
#  'препаратов': 769,
#  'голеней': 770,
#  'стоп': 771,
#  'синусовый': 772,
#  'режим': 773,
#  'питание': 774,
#  'оар': 775,
#  'прием': 776,
#  'госпитализирована': 777,
#  'е': 778,
#  'остальном': 779,
#  'сопутствующие': 780,
#  'срб': 781,
#  'пациентка': 782,
#  'пп': 783,
#  'катетеру': 784,
#  'ивл': 785,
#  'моча': 786,
#  'бедра': 787,
#  'положение': 788,
#  'данных': 789,
#  'сохранен': 790,
#  'мк': 791,
#  'трикуспидальня': 792,
#  'риском': 793,
#  'экстрасистолии': 794,
#  'хирурга': 795,
#  'исследование': 796,
#  'критических': 797,
#  'растворами': 798,
#  'боль': 799,
#  'умеренная': 800,
#  'мокроты': 801,
#  'нижней': 802,
#  'инф': 803,
#  'температуры': 804,
#  'предъявляет': 805,
#  'связи': 806,
#  'лёгкой': 807,
#  'легкого': 808,
#  'боковой': 809,
#  'сатурации': 810,
#  'peep': 811,
#  '52': 812,
#  'so2': 813,
#  'рот': 814,
#  'мониторинг': 815,
#  'клиника': 816,
#  'историей': 817,
#  'отриц': 818,
#  'ркт': 819,
#  'команды': 820,
#  'аускультативно': 821,
#  'белково': 822,
#  'гипертрофия': 823,
#  'вечером': 824,
#  'ритма': 825,
#  'инъекций': 826,
#  'совместно': 827,
#  'выписке': 828,
#  'ж': 829,
#  'признаками': 830,
#  'высокая': 831,
#  'апикального': 832,
#  'доступа': 833,
#  'час': 834,
#  'удовлетворительное': 835,
#  'высоким': 836,
#  'тэо': 837,
#  '15л': 838,
#  'кислородной': 839,
#  'гкб': 840,
#  'подтверждённая': 841,
#  'iia': 842,
#  'sars': 843,
#  'анамнезе': 844,
#  'риск4': 845,
#  'неизвестной': 846,
#  'венозная': 847,
#  'осмотр': 848,
#  'сovid': 849,
#  'маски': 850,
#  'ощущает': 851,
#  'недостаточноть': 852,
#  'хснпфв': 853,
#  'iiб': 854,
#  'двусторонний': 855,
#  'внезапной': 856,
#  'контуры': 857,
#  'почек': 858,
#  'объективно': 859,
#  'гипергликемия': 860,
#  'пароксизм': 861,
#  '7ос': 862,
#  'дэ': 863,
#  'чувство': 864,
#  'глубоких': 865,
#  'патологии': 866,
#  'сердце': 867,
#  'аг': 868,
#  'qt': 869,
#  'акроцианоз': 870,
#  'spo2': 871,
#  'мышц': 872,
#  'парезов': 873,
#  'утомляемость': 874,
#  'лекарственных': 875,
#  '69': 876,
#  'интенсивная': 877,
#  'ит': 878,
#  'интенсивной': 879,
#  'продолжения': 880,
#  'положительная': 881,
#  'направлена': 882,
#  'pq': 883,
#  'контрастного': 884,
#  'усиления': 885,
#  '79': 886,
#  'двусторонней': 887,
#  'выполняет': 888,
#  'бледный': 889,
#  'сосудистая': 890,
#  'зоны': 891,
#  'мероприятия': 892,
#  'предсердий': 893,
#  'конечностей': 894,
#  'расширены': 895,
#  'легочный': 896,
#  'усилен': 897,
#  'верхних': 898,
#  'ног': 899,
#  'меньше': 900,
#  'местах': 901,
#  'обход': 902,
#  'самообслуживание': 903,
#  'врача': 904,
#  'кпос': 905,
#  'литров': 906,
#  'пж': 907,
#  'увеличено': 908,
#  'но': 909,
#  'дыхательных': 910,
#  'микрососудистый': 911,
#  'критика': 912,
#  'зав': 913,
#  'рекомендовано': 914,
#  'хсн1': 915,
#  'фк1': 916,
#  'хр': 917,
#  'активнее': 918,
#  'жалоб': 919,
#  'поводу': 920,
#  'неивестной': 921,
#  'мфа': 922,
#  'культя': 923,
#  'частичной': 924,
#  'дыхательной': 925,
#  'сепсис': 926,
#  'вероятный': 927,
#  'интубационную': 928,
#  'полинейропатия': 929,
#  'ровные': 930,
#  'klebsiella': 931,
#  'см': 932,
#  'ордс': 933,
#  'распр': 934,
#  'цитокиновый': 935,
#  'шторм': 936,
#  'маркер': 937,
#  'зоб': 938,
#  'удовлетворительный': 939,
#  '2008г': 940,
#  'акш': 941,
#  '2008': 942,
#  'антисептиков': 943,
#  'сроке': 944,
#  'недель': 945,
#  'послеродовое': 946,
#  'гестационный': 947,
#  'гипотиреоз': 948,
#  'отрицает': 949,
#  'стекла': 950,
#  'мочи': 951,
#  'смешанная': 952,
#  'переведен': 953,
#  '135': 954,
#  'тропонин': 955,
#  'лёгких': 956,
#  'v6': 957,
#  'преднизолон': 958,
#  'нивл': 959,
#  'размеры': 960,
#  'активные': 961,
#  'морбидное': 962,
#  'железы': 963,
#  'кормится': 964,
#  'гиса': 965,
#  'респираторная': 966,
#  'динамикой': 967,
#  'обложен': 968,
#  'особенности': 969,
#  'уровня': 970,
#  'кср': 971,
#  'кдр': 972,
#  'ксо': 973,
#  'фс': 974,
#  'периферических': 975,
#  'лихорадка': 976,
#  'сердечно': 977,
#  'система': 978,
#  'воспаления': 979,
#  'пациентки': 980,
#  'цифр': 981,
#  'изменения': 982,
#  'принимает': 983,
#  'ясные': 984,
#  'rg': 985,
#  'контролирует': 986,
#  'артериальная': 987,
#  'форма': 988,
#  'степень': 989,
#  '025': 990,
#  'цвет': 991,
#  'светло': 992,
#  '250': 993,
#  'igg': 994,
#  'неврологически': 995,
#  'года': 996,
#  'субкомпенсация': 997,
#  '125': 998,
#  'лп': 999,
#  'ветвь': 1000,
#  ...}

# %%
#create sequenses
sequences_text = tokenizer_text.texts_to_sequences(text_subframe)
print(text_subframe.iloc[814])
print(sequences_text[814])

maxlen = text_subframe.str.len().max()
print(maxlen)
# Out:
#  Дыхание ослаблено слева ,  ослаблено справа .  Хрипы отсутствуют .  Одышка при ФН .  В акте дыхания вспомогательная мускулатура не участвует .  ЧД 21  в мин .  Сатурация 98  %  сидя на О 2 терапии 7 л/мин  ,  на атмосферном воздухе 90  %  .
# [27, 211, 215, 3, 211, 156, 2, 29, 84, 2, 23, 17, 46, 2, 4, 55, 50, 62, 64, 20, 63, 2, 35, 73, 4, 15, 2, 22, 104, 9, 77, 10, 181, 16, 146, 48, 6, 15, 3, 10, 364, 54, 65, 9, 2]
# 4850

# %%
max_text_len = 300
sequences_padded = pad_sequences(sequences_text, maxlen=max_text_len, padding='pre', truncating='pre')

params_data = df["Parameters"]

print(len(sequences_text[814]))
print(len(sequences_padded[814]))
print(type(params_data))
# Out:
# 45
# 300
# <class 'pandas.core.series.Series'>

# %%
test_split = 0.2

seq_train_df, seq_testval_df, params_train_df, params_testval_df = train_test_split(
    sequences_padded,
    params_data,
    test_size=test_split,
    random_state=42,
    shuffle=True
)

print("training set of sequences: ", len(seq_train_df))
print("test set of sequences:", len(seq_testval_df))
print("training set of params", len(params_train_df))
print("test set of params", len(params_testval_df))
# Out:
# training set of sequences:  1302
# test set of sequences: 326
# training set of params 1302
# test set of params 326

# %%
seq_val_df, seq_test_df, params_val_df, params_test_df = train_test_split(
    seq_testval_df,
    params_testval_df,
    test_size=0.5,
    random_state=42,
    shuffle=True
)

# %%
print(params_test_df[:5])
print(seq_test_df[:5])
# Out:
# 1929    1
# 444     0
# 412     0
# 75      1
# 508     1
# Name: Parameters, dtype: object
# [[   0    0    0 ... 1469  743    2]
#  [   0    0    0 ...  453   38    2]
#  [   0    0    0 ...   28  358    3]
#  [   0    0    0 ...  655    2    2]
#  [   0    0    0 ...    4   15    2]]

# %%
params_train_binarized = tf.keras.utils.to_categorical(
    params_train_df, num_classes=3, dtype='float32'
)

params_test_binarized = tf.keras.utils.to_categorical(
    params_test_df, num_classes=3, dtype='float32'
)

params_val_binarized = tf.keras.utils.to_categorical(
    params_val_df, num_classes=3, dtype='float32'
)

print(params_test_binarized.shape)
print(params_train_binarized.shape)
print(params_val_binarized.shape)
# Out:
# (163, 3)
# (1302, 3)
# (163, 3)

# %%
print(params_train_binarized[:5])
print(params_train_df[:5])
# Out:
# [[1. 0. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]]
# 239     0
# 1783    2
# 324     0
# 485     0
# 1558    1
# Name: Parameters, dtype: object

# %%
print(seq_train_df)
# Out:
# [[   0    0    0 ... 1531    2    2]
#  [   0    0    0 ...   12    2   14]
#  [   0    0    0 ...  877  154    2]
#  ...
#  [   0    0    0 ... 4154   70   36]
#  [   0    0    0 ... 1140  341    2]
#  [   0    0    0 ...  231 4415    2]]

# %%
lstm_drop=0.1
input_shape = (seq_train_df.shape[1])
model_input = Input(shape=input_shape)
embedding = Embedding(num_words, 128) (model_input)
lstm = LSTM(129, dropout=lstm_drop, return_sequences=True) (embedding)
flat = Flatten()(lstm)
out = Dense(3, activation="sigmoid")(flat)
model = Model(model_input, out)
loss = 'binary_crossentropy'
optimizer = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)#increased lr to 0.001
#optimizer = optimizers.SGD(lr=0.01)
metrics='accuracy'
model.compile(optimizer=optimizer,loss=loss,metrics=[metrics, tf.keras.metrics.MeanIoU(num_classes=2, name='mean_io_u')])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 300)]             0
#
#  embedding_1 (Embedding)     (None, 300, 128)          768000
#
#  lstm_1 (LSTM)               (None, 300, 129)          133128
#
#  flatten_1 (Flatten)         (None, 38700)             0
#
#  dense_4 (Dense)             (None, 3)                 116103
#
# =================================================================
# Total params: 1,017,231
# Trainable params: 1,017,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
check_path= folder_path + "model-with-empty-param-checkpoints"

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight(
                                        class_weight = 'balanced',
                                        classes = np.unique(params_train_df),
                                        y = params_train_df            
                                    )
class_weights = dict(zip(np.unique(params_train_df), class_weights))
class_weights
# Out:
# {0: 0.8493150684931506, 1: 0.6823899371069182, 2: 2.8}

# %%
epochs = 40

callbacks = [
     ModelCheckpoint(check_path, monitor='val_mean_io_u', save_best_only=True, verbose=0),
]

history = model.fit(
    seq_train_df,
    params_train_binarized,
    validation_data=(seq_val_df, params_val_binarized),                    
    epochs = epochs,
    batch_size=10,
    class_weight = {0: 0.3,
                1: 0.24,
                2: 1},
    callbacks=callbacks
)

def plot_result(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_"+item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train over {} epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()

plot_result("loss")
plot_result("mean_io_u")
# Out:
# Epoch 1/40
#  26/131 [====>.........................] - ETA: 38s - loss: 0.2230 - accuracy: 0.5000 - mean_io_u: 0.3333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b97fbbf69730> in <module>
#       5 ]
#       6
# ----> 7 history = model.fit(
#       8     seq_train_df,
#       9     params_train_binarized,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1648                         ):
#    1649                             callbacks.on_train_batch_begin(step)
# -> 1650                             tmp_logs = self.train_function(iterator)
#    1651                             if data_handler.should_sync:
#    1652                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     910       # In this case we have created variables on the first call, so we run the
#     911       # defunned version which is guaranteed to never create variables.
# --> 912       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913     elif self._variable_creation_fn is not None:
#     914       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
_, acc, mean_io_u = model.evaluate(seq_test_df, params_test_binarized)
print(f"Accuracy on the test set: {round(mean_io_u *100, 2)}%")
# Out:
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0762 - accuracy: 0.9816 - mean_io_u: 0.7591
# Accuracy on the test set: 75.91%

# %%
model = models.load_model(check_path)

# %%
def preprocess_text(line):
  tokenized_string = tokenizer_text.texts_to_sequences([line])
  padded_sequence = pad_sequences(tokenized_string, maxlen=max_text_len)
  return padded_sequence

# %%
test_string = preprocess_text("Лимфоциты # (Lym)")
result = model.predict(tf.convert_to_tensor(test_string))
print(result)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# [[7.8396624e-01 1.2258079e-03 5.4419308e-04]]
